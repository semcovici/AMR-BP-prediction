# %%
import conllu
import pandas as pd
from tqdm import tqdm
import numpy as np

# %% [markdown]
# http://www.nilc.icmc.usp.br/semanticnlp/index.php?id=index&id_sub=principal&dir_sub=includes/projects/propbankbr&dir=includes/projects/propbankbr&lang=pt-br#palmeretal2005

# %% [markdown]
# Índice: Número da palavra na frase.
# Forma: A forma original da palavra na frase.
# Lema: O lema ou a forma base da palavra.
# POS (Part of Speech): Categoria gramatical da palavra (por exemplo, n = substantivo, v = verbo, adj = adjetivo, etc.).
# Características Morfológicas: Informações morfológicas da palavra (por exemplo, gênero e número).
# ID da Cabeça (Head ID): Índice da palavra que é a cabeça da dependência.
# Relação de Dependência: Relação de dependência entre a palavra e sua cabeça (por exemplo, SUBJ = sujeito, OBJ = objeto, etc.).
# Verificação de Sujeito Nulo (Null Subject Check): Indica se a palavra está envolvida em uma verificação de sujeito nulo (Y = sim, N = não).
# Lema do Verbo Principal (Main Verb Lemma): O lema do verbo principal da frase.
# Argumento 0 (A0): Marcador do argumento 0 (frequentemente o sujeito) do verbo.
# Argumento 1 (A1): Marcador do argumento 1 (frequentemente o objeto) do verbo.
# Argumento 2 (A2): Marcador do argumento 2 do verbo (se aplicável).
# Argumento Modificador (AM-*): Marcadores de modificadores adicionais (por exemplo, AM-LOC para localização, AM-ADV para advérbio, etc.).

# %%
path = '../data/raw/propbankbr_v1.1_conll/PropBankBr_v1.1_Dep.conll.txt'

# Open the plain text file for reading; assign under 'data'
with open(path, mode="r", encoding="utf-8") as data:
    
    # Read the file contents and assign under 'annotations'
    annotations = data.read()

# %%
sents = annotations.split("\n\n")
sents = [sent for sent in sents if sent != '']

# %%
list_dict_an = []
propbank_id = 0
for sent in tqdm(sents):
    
    propbank_id += 1
    
    dict_an = {}

    tks = sent.split("\n")
    tks = [tk for tk in tks if tk != ""]
    
    list_id = []
    list_form = []
    list_lemma = []
    list_postag = []
    list_morph = []
    list_head_id = []
    list_deprel = []
    list_null_sujeito = []
    list_main_verb_lemma = []

    args_list = []
    
    
    dict_an_snt = {}
    for id_tk, tk in enumerate(tks):

        tk_an = tk.split()

        # pega as 10 caracteristicas (colunas) fixas (as restantes sao args)
        id, form, lemma, postag, morph, head_id, deprel, null_sujeito, main_verb_lemma  = tk_an[:9]
        
        id = int(id)
        form = form.replace(" ", "")
        lemma = lemma.replace(" ", "")
        postag = postag.replace(" ", "")
        morph = morph.replace(" ", "")
        head_id = head_id.replace(" ", "") 
        deprel = deprel.replace(" ", "") 
        null_sujeito = null_sujeito.replace(" ", "")
        main_verb_lemma = main_verb_lemma.replace(" ", "")
        
        
        list_id.append(id)
        list_form.append(form)
        list_lemma.append(lemma)
        list_postag.append(postag) 
        list_morph.append(morph) 
        list_head_id.append(head_id) 
        list_deprel.append(deprel) 
        list_null_sujeito.append(null_sujeito) 
        list_main_verb_lemma.append(main_verb_lemma) 

        # get args 
        args = tk_an[9:len(tk_an)]
        # format  
        args = [arg.replace(" ", "")  for arg in args]
        
        
        
        args_list.append(np.array(args))
        
        dict_an_snt.update({
            id_tk:{
                "id": id,
                "form": form,
                "lemma": lemma,
                "postag": postag, 
                "morph": morph, 
                "head_id": head_id, 
                "deprel": deprel, 
                "null_sujeito": null_sujeito, 
                "main_verb_lemma": main_verb_lemma
            }
        })

    sentence = " ".join(list_form)
    
    
    dict_an.update({"id": "propbank" + "_" + str(propbank_id)})
    dict_an.update({"snt":sentence})
    dict_an.update({"annotated_sentence_gold":dict_an_snt})
    list_dict_an.append(dict_an)
    
    tuples_root_verb = [(i, verb) for i,  verb in enumerate(list_main_verb_lemma) if verb != "-"]
    
    roots_position, root_verbs = list(map(list, zip(*tuples_root_verb)))

    
    if -1 in roots_position:
        print("Não foi achado o root")
        
        
    args_mtx = np.array(args_list)
    args_df = pd.DataFrame(args_mtx, columns = [f"{root_verbs[i]}_{roots_position[i]}" for i in range(len(root_verbs))], index=list_id)
    # replace * with nan (all the values are ARGS or V now)
    args_df.replace('-', np.nan, inplace=True)
    
    args_df.dropna(how="all", inplace = True)

    not_root_position = [id - 1 for id in args_df.index.tolist()]

    nodes_tk_ids = set(not_root_position + roots_position)


    nodes = {}
    node_id = 0
    for tk_id in nodes_tk_ids:
        
        node_id+=1
        
        nodes.update({
            node_id: list_lemma[tk_id]
        })

    dict_an.update({"nodes": nodes})


    edge_id = 0
    edges = {}

    for col in args_df.columns:
        
        root_verb, root_verb_position = col.split("_")
        
        args_verb = args_df[col].dropna()

        for idx, arg in args_verb.items():
            
            tk_position = idx - 1
            
            lemma = list_lemma[tk_position]
            
            edge_id+=1
            edges.update({
                f"edge {edge_id}": {
                    "nodes_ids": (root_verb_position, str(tk_position)),
                    "nodes": (root_verb, lemma),
                    "value": arg
                }
            })
            
    dict_an.update({"edges": edges})
# Out:
#   5%|▍         | 163/3348 [00:00<00:03, 810.47it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#   7%|▋         | 245/3348 [00:00<00:03, 802.47it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  17%|█▋        | 579/3348 [00:00<00:03, 819.69it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  25%|██▍       | 829/3348 [00:01<00:03, 777.95it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  27%|██▋       | 908/3348 [00:01<00:03, 779.65it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  30%|██▉       | 990/3348 [00:01<00:02, 788.96it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  37%|███▋      | 1237/3348 [00:01<00:02, 808.86it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  42%|████▏     | 1407/3348 [00:01<00:02, 826.47it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  45%|████▍     | 1494/3348 [00:01<00:02, 839.31it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  50%|████▉     | 1665/3348 [00:02<00:01, 841.56it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  55%|█████▍    | 1836/3348 [00:02<00:01, 836.50it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  57%|█████▋    | 1921/3348 [00:02<00:01, 838.10it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  63%|██████▎   | 2093/3348 [00:02<00:01, 847.35it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  65%|██████▌   | 2178/3348 [00:02<00:01, 844.12it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  70%|███████   | 2349/3348 [00:02<00:01, 845.43it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  81%|████████  | 2698/3348 [00:03<00:00, 864.26it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  83%|████████▎ | 2785/3348 [00:03<00:00, 860.08it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  86%|████████▌ | 2872/3348 [00:03<00:00, 861.38it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  88%|████████▊ | 2959/3348 [00:03<00:00, 859.97it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  94%|█████████▎| 3136/3348 [00:03<00:00, 865.62it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
#  96%|█████████▋| 3223/3348 [00:03<00:00, 858.09it/s]/tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_214668/4122099624.py:97: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   args_df.replace('-', np.nan, inplace=True)
# 100%|██████████| 3348/3348 [00:04<00:00, 830.38it/s]

# %%
dict_an
# Out:
# {'id': 'propbank_3348',
#  'snt': 'Além_de Mauro_Salles que surpreendeu a galera a o revelar seu côté de fotógrafo profissional em o ínico de a carreira , o foco principal de o encontro foi a mulher de J.R.Duran , Alexandra_Brochen .',
#  'annotated_sentence_gold': {0: {'id': 1,
#    'form': 'Além_de',
#    'lemma': 'além_de',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '28',
#    'deprel': 'ADVL',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   1: {'id': 2,
#    'form': 'Mauro_Salles',
#    'lemma': 'Mauro_Salles',
#    'postag': 'prop',
#    'morph': 'M|S',
#    'head_id': '1',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   2: {'id': 3,
#    'form': 'que',
#    'lemma': 'que',
#    'postag': 'pron-indp',
#    'morph': 'M|S',
#    'head_id': '4',
#    'deprel': 'SUBJ',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   3: {'id': 4,
#    'form': 'surpreendeu',
#    'lemma': 'surpreender',
#    'postag': 'v-fin',
#    'morph': 'PS|3S|IND',
#    'head_id': '2',
#    'deprel': 'N<',
#    'null_sujeito': 'Y',
#    'main_verb_lemma': 'surpreender'},
#   4: {'id': 5,
#    'form': 'a',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'F|S',
#    'head_id': '6',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   5: {'id': 6,
#    'form': 'galera',
#    'lemma': 'galera',
#    'postag': 'n',
#    'morph': 'F|S',
#    'head_id': '4',
#    'deprel': 'ACC',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   6: {'id': 7,
#    'form': 'a',
#    'lemma': 'a',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '4',
#    'deprel': 'ADVL',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   7: {'id': 8,
#    'form': 'o',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'M|S',
#    'head_id': '9',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   8: {'id': 9,
#    'form': 'revelar',
#    'lemma': 'revelar',
#    'postag': 'v-inf',
#    'morph': '-',
#    'head_id': '7',
#    'deprel': 'P<',
#    'null_sujeito': 'Y',
#    'main_verb_lemma': 'revelar'},
#   9: {'id': 10,
#    'form': 'seu',
#    'lemma': 'seu',
#    'postag': 'pron-det',
#    'morph': 'M|S',
#    'head_id': '11',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   10: {'id': 11,
#    'form': 'côté',
#    'lemma': 'côté',
#    'postag': 'n',
#    'morph': 'M|S',
#    'head_id': '9',
#    'deprel': 'ACC',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   11: {'id': 12,
#    'form': 'de',
#    'lemma': 'de',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '11',
#    'deprel': 'N<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   12: {'id': 13,
#    'form': 'fotógrafo',
#    'lemma': 'fotógrafo',
#    'postag': 'n',
#    'morph': 'M|S',
#    'head_id': '12',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   13: {'id': 14,
#    'form': 'profissional',
#    'lemma': 'profissional',
#    'postag': 'adj',
#    'morph': 'M|S',
#    'head_id': '13',
#    'deprel': 'N<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   14: {'id': 15,
#    'form': 'em',
#    'lemma': 'em',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '9',
#    'deprel': 'ADVL',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   15: {'id': 16,
#    'form': 'o',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'M|S',
#    'head_id': '15',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   16: {'id': 17,
#    'form': 'ínico',
#    'lemma': 'início',
#    'postag': 'n',
#    'morph': 'M|S',
#    'head_id': '16',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   17: {'id': 18,
#    'form': 'de',
#    'lemma': 'de',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '17',
#    'deprel': 'N<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   18: {'id': 19,
#    'form': 'a',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'F|S',
#    'head_id': '20',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   19: {'id': 20,
#    'form': 'carreira',
#    'lemma': 'carreira',
#    'postag': 'n',
#    'morph': 'F|S',
#    'head_id': '18',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   20: {'id': 21,
#    'form': ',',
#    'lemma': ',',
#    'postag': 'pu',
#    'morph': '-',
#    'head_id': '28',
#    'deprel': 'PU',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   21: {'id': 22,
#    'form': 'o',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'M|S',
#    'head_id': '23',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   22: {'id': 23,
#    'form': 'foco',
#    'lemma': 'foco',
#    'postag': 'n',
#    'morph': 'M|S',
#    'head_id': '28',
#    'deprel': 'SUBJ',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   23: {'id': 24,
#    'form': 'principal',
#    'lemma': 'principal',
#    'postag': 'adj',
#    'morph': 'M|S',
#    'head_id': '23',
#    'deprel': 'N<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   24: {'id': 25,
#    'form': 'de',
#    'lemma': 'de',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '23',
#    'deprel': 'N<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   25: {'id': 26,
#    'form': 'o',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'M|S',
#    'head_id': '27',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   26: {'id': 27,
#    'form': 'encontro',
#    'lemma': 'encontro',
#    'postag': 'n',
#    'morph': 'M|S',
#    'head_id': '25',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   27: {'id': 28,
#    'form': 'foi',
#    'lemma': 'ser',
#    'postag': 'v-fin',
#    'morph': 'PS|3S|IND',
#    'head_id': '0',
#    'deprel': 'STA',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   28: {'id': 29,
#    'form': 'a',
#    'lemma': 'o',
#    'postag': 'art',
#    'morph': 'F|S',
#    'head_id': '30',
#    'deprel': '>N',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   29: {'id': 30,
#    'form': 'mulher',
#    'lemma': 'mulher',
#    'postag': 'n',
#    'morph': 'F|S',
#    'head_id': '28',
#    'deprel': 'SC',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   30: {'id': 31,
#    'form': 'de',
#    'lemma': 'de',
#    'postag': 'prp',
#    'morph': '-',
#    'head_id': '30',
#    'deprel': 'N<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   31: {'id': 32,
#    'form': 'J.R.Duran',
#    'lemma': 'J.R.Duran',
#    'postag': 'prop',
#    'morph': 'M|S',
#    'head_id': '31',
#    'deprel': 'P<',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   32: {'id': 33,
#    'form': ',',
#    'lemma': ',',
#    'postag': 'pu',
#    'morph': '-',
#    'head_id': '32',
#    'deprel': 'PU',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   33: {'id': 34,
#    'form': 'Alexandra_Brochen',
#    'lemma': 'Alexandra_Brochen',
#    'postag': 'prop',
#    'morph': 'F|S',
#    'head_id': '32',
#    'deprel': 'APP',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'},
#   34: {'id': 35,
#    'form': '.',
#    'lemma': '.',
#    'postag': 'pu',
#    'morph': '-',
#    'head_id': '28',
#    'deprel': 'PU',
#    'null_sujeito': '-',
#    'main_verb_lemma': '-'}},
#  'nodes': {1: 'que',
#   2: 'surpreender',
#   3: 'galera',
#   4: 'a',
#   5: 'revelar',
#   6: 'côté',
#   7: 'em'},
#  'edges': {'edge 1': {'nodes_ids': ('3', '2'),
#    'nodes': ('surpreender', 'que'),
#    'value': 'A0'},
#   'edge 2': {'nodes_ids': ('3', '5'),
#    'nodes': ('surpreender', 'galera'),
#    'value': 'A1'},
#   'edge 3': {'nodes_ids': ('3', '6'),
#    'nodes': ('surpreender', 'a'),
#    'value': 'AM-TMP'},
#   'edge 4': {'nodes_ids': ('8', '10'),
#    'nodes': ('revelar', 'côté'),
#    'value': 'A1'},
#   'edge 5': {'nodes_ids': ('8', '14'),
#    'nodes': ('revelar', 'em'),
#    'value': 'AM-TMP'}}}
